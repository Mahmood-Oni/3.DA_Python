# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://dvx78774:j0mTJKkaFz2VplvP@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB?security=SSL

# %%
# %sql select TABNAME,TABSCHEMA,CREATE_TIME from SYSCAT.TABLES
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('SYSTABLES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLUMNS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSVIEWS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSVIEWDEP', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSPLAN', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSPLANDEP', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSECTION', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSTMT', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSDBAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSPLANAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTABAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSRELS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSROUTINES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSROUTINEPARMS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTABCONST', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSKEYCOLUSE', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCHECKS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLCHECKS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSDATATYPES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCONSTDEP', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLDIST', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSEVENTMONITORS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSEVENTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTABLESPACES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSDEPENDENCIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTRIGGERS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSCHEMAAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSCHEMATA', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSUSERAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSNODEGROUPDEF', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSNODEGROUPS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSPARTITIONMAPS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSBUFFERPOOLS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSBUFFERPOOLNODES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLPROPERTIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSATTRIBUTES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSHIERARCHIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTBSPACEAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLOPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSFUNCMAPOPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSFUNCMAPPARMOPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSFUNCMAPPINGS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXEXPLOITRULES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXEXTENSIONPARMS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXEXTENSIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXEXTENSIONMETHODS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXOPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSPASSTHRUAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSPREDICATESPECS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTYPEMAPPINGS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSERVEROPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSERVERS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTABOPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTRANSFORMS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSUSEROPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWRAPOPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWRAPPERS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSJARCONTENTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSJAROBJECTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSNAMEMAPPINGS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSEQUENCES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXCOLUSE', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSVERSIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLUSE', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSROUTINEAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSLIBRARIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSLIBRARYBINDFILES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSLIBRARYVERSIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLGROUPS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLGROUPSCOLS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLGROUPDIST', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLGROUPDISTCOUNTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSLIBRARYAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSEVENTTABLES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSROUTINEPROPERTIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOMMENTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSEQUENCEAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCODEPROPERTIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSXMLSTRINGS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSXMLPATHS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSXSROBJECTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSXSROBJECTCOMPONENTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSXSROBJECTAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSXSROBJECTHIERARCHIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXXMLPATTERNS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSXDBMAPGRAPHS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSXDBMAPSHREDTREES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSDATAPARTITIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSDATAPARTITIONEXPRESSION', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSJOBS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTASKS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTUNINGINFO', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSECURITYLABELCOMPONENTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSECURITYLABELCOMPONENTELEMENTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSECURITYPOLICIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSECURITYPOLICYCOMPONENTRULES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSECURITYLABELS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSECURITYLABELACCESS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSECURITYPOLICYEXEMPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSURROGATEAUTHIDS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSROUTINEOPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSROUTINEPARMOPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSROLES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSROLEAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCONTEXTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCONTEXTATTRIBUTES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLLATIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSVARIABLES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSVARIABLEAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWORKLOADS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWORKLOADCONNATTR', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWORKLOADAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSERVICECLASSES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWORKCLASSSETS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWORKCLASSES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWORKACTIONSETS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWORKACTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSTHRESHOLDS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSHISTOGRAMTEMPLATES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSHISTOGRAMTEMPLATEBINS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSHISTOGRAMTEMPLATEUSE', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSAUDITUSE', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSAUDITPOLICIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSMODULEAUTH', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSMODULES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINVALIDOBJECTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSINDEXPARTITIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSPERIODS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCONTROLS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSCOLDEPENDENCIES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSTOGROUPS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSUSAGELISTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSTATEMENTTEXTS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSWORKCLASSATTRIBUTES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSSCPREFTBSPACES', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSUPGRADERUNSTATSTASKS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSAUDITEXCEPTIONS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSMEMBERSUBSETS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSMEMBERSUBSETATTRS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSMEMBERSUBSETMEMBERS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSENVIRONMENT', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSEXTTAB', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSEXTTABFILEOBJ', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('SYSEXTTABCOLS', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 13, 669091)),
#  ('DUAL', 'SYSPUBLIC', datetime.datetime(2020, 6, 15, 14, 29, 27, 907994)),
#  ('SYSDUMMY1', 'SYSIBM  ', datetime.datetime(2020, 6, 15, 14, 29, 28, 207126)),
#  ('SYSCOLPROPERTIES_UNION', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 503887)),
#  ('SYSCOLUMNS_UNION', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 649811)),
#  ('SYSDATATYPES_UNION', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 691250)),
#  ('SYSTABLES_UNION', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 730939)),
#  ('CHECK_CONSTRAINTS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 756911)),
#  ('COLUMNS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 783320)),
#  ('DUAL', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 809633)),
#  ('COLUMNS_S', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 825733)),
#  ('REFERENTIAL_CONSTRAINTS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 846256)),
#  ('REF_CONSTRAINTS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 874175)),
#  ('TABLE_CONSTRAINTS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 890957)),
#  ('TABLES', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 921999)),
#  ('TABLES_S', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 951576)),
#  ('USER_DEFINED_TYPES', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 33, 967861)),
#  ('UDT_S', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 6676)),
#  ('VIEWS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 25628)),
#  ('PARAMETERS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 49867)),
#  ('PARAMETERS_S', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 96554)),
#  ('ROUTINES', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 119960)),
#  ('ROUTINES_S', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 163458)),
#  ('SYSFUNCTIONS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 191646)),
#  ('SYSPROCEDURES', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 219039)),
#  ('SYSFUNCPARMS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 245047)),
#  ('SYSPROCPARMS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 265114)),
#  ('SYSREVTYPEMAPPINGS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 282042)),
#  ('SYSROUTINEPROPERTIESJAVA', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 321967)),
#  ('ATTRIBUTES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 341585)),
#  ('AUDITPOLICIES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 387279)),
#  ('COLGROUPDIST', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 601316)),
#  ('COLGROUPDISTCOUNTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 619662)),
#  ('COLGROUPS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 638224)),
#  ('COLIDENTATTRIBUTES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 655828)),
#  ('COLLATIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 679468)),
#  ('COLOPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 694403)),
#  ('COLUMNS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 709530)),
#  ('COLUSE', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 864040)),
#  ('CONDITIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 898681)),
#  ('CONSTDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 914784)),
#  ('CONTEXTATTRIBUTES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 939395)),
#  ('CONTEXTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 953632)),
#  ('CONTROLDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 967210)),
#  ('CONTROLS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 765)),
#  ('AUDITUSE', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 408225)),
#  ('BUFFERPOOLDBPARTITIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 427453)),
#  ('BUFFERPOOLEXCEPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 443726)),
#  ('BUFFERPOOLNODES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 455172)),
#  ('BUFFERPOOLS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 467018)),
#  ('CASTFUNCTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 483325)),
#  ('CHECKS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 498562)),
#  ('COLAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 521460)),
#  ('COLCHECKS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 547748)),
#  ('COLDIST', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 567815)),
#  ('COLGROUPCOLS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 34, 583624)),
#  ('DATATYPEDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 104641)),
#  ('DATATYPES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 136661)),
#  ('DATAPARTITIONEXPRESSION', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 38172)),
#  ('DATAPARTITIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 66497)),
#  ('DBAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 191850)),
#  ('POLICY', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 44, 41, 834904)),
#  ('HMON_ATM_INFO', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 44, 42, 754649)),
#  ('HMON_COLLECTION', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 44, 42, 837606)),
#  ('EXPLAIN_INSTANCE', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 26, 509209)),
#  ('EXPLAIN_STATEMENT', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 26, 573817)),
#  ('EXPLAIN_ARGUMENT', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 26, 708276)),
#  ('EXPLAIN_OBJECT', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 26, 780751)),
#  ('EXPLAIN_OPERATOR', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 26, 818740)),
#  ('EXPLAIN_PREDICATE', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 26, 917345)),
#  ('EXPLAIN_STREAM', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 3941)),
#  ('EXPLAIN_DIAGNOSTIC', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 85709)),
#  ('EXPLAIN_DIAGNOSTIC_DATA', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 167169)),
#  ('OBJECT_METRICS', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 239585)),
#  ('ADVISE_INSTANCE', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 335816)),
#  ('ADVISE_INDEX', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 419300)),
#  ('ADVISE_WORKLOAD', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 497570)),
#  ('ADVISE_MQT', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 550349)),
#  ('ADVISE_PARTITION', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 614995)),
#  ('ADVISE_TABLE', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 27, 676215)),
#  ('EXPLAIN_ACTUALS', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 52, 28, 250274)),
#  ('IDAX_MODELS', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 54, 0, 756509)),
#  ('IDAX_COMPONENTS', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 54, 0, 837743)),
#  ('IDAX_PARAMS', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 54, 0, 910000)),
#  ('IDAX_COLPROPS', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 54, 0, 978286)),
#  ('DIST_SPARK', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 54, 6, 576548)),
#  ('LOCAL_SPARK', 'SYSTOOLS', datetime.datetime(2020, 6, 15, 14, 54, 6, 632910)),
#  ('DBPARTITIONGROUPDEF', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 209323)),
#  ('DBPARTITIONGROUPS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 222466)),
#  ('EXTERNALTABLEOPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 236591)),
#  ('EVENTMONITORS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 284827)),
#  ('EVENTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 321382)),
#  ('EVENTTABLES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 334202)),
#  ('FULLHIERARCHIES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 367427)),
#  ('FUNCDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 387647)),
#  ('FUNCMAPOPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 407497)),
#  ('FUNCMAPPARMOPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 439192)),
#  ('FUNCMAPPINGS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 464469)),
#  ('HIERARCHIES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 594296)),
#  ('HISTOGRAMTEMPLATEBINS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 619977)),
#  ('FUNCPARMS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 491914)),
#  ('FUNCTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 511967)),
#  ('HISTOGRAMTEMPLATES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 639767)),
#  ('HISTOGRAMTEMPLATEUSE', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 656010)),
#  ('INDEXAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 679133)),
#  ('INDEXCOLUSE', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 720197)),
#  ('INDEXDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 754785)),
#  ('INDEXES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 785513)),
#  ('INDEXEXPLOITRULES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 916835)),
#  ('INDEXEXTENSIONDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 948028)),
#  ('INDEXEXTENSIONMETHODS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 35, 973094)),
#  ('INDEXEXTENSIONPARMS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 14886)),
#  ('INDEXEXTENSIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 43203)),
#  ('INDEXOPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 69881)),
#  ('INDEXPARTITIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 88717)),
#  ('INDEXXMLPATTERNS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 141212)),
#  ('INVALIDOBJECTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 174524)),
#  ('KEYCOLUSE', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 198746)),
#  ('LIBRARIES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 216884)),
#  ('LIBRARYAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 243887)),
#  ('LIBRARYBINDFILES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 276485)),
#  ('LIBRARYVERSIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 296938)),
#  ('MEMBERSUBSETS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 317148)),
#  ('MEMBERSUBSETATTRS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 334679)),
#  ('MEMBERSUBSETMEMBERS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 354286)),
#  ('MODULEAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 381004)),
#  ('MODULEOBJECTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 444216)),
#  ('MODULES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 461089)),
#  ('NAMEMAPPINGS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 493464)),
#  ('NICKNAMES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 516117)),
#  ('NODEGROUPDEF', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 540738)),
#  ('NODEGROUPS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 553044)),
#  ('PACKAGEAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 568267)),
#  ('PACKAGEDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 586683)),
#  ('PACKAGES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 608928)),
#  ('PARTITIONMAPS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 636714)),
#  ('PASSTHRUAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 661768)),
#  ('PERIODS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 690562)),
#  ('PREDICATESPECS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 711893)),
#  ('PROCEDURES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 734215)),
#  ('PROCPARMS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 750326)),
#  ('REFERENCES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 765855)),
#  ('ROLEAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 787937)),
#  ('ROLES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 809615)),
#  ('ROUTINEAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 866039)),
#  ('ROUTINEDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 896027)),
#  ('ROUTINEOPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 927875)),
#  ('ROUTINEPARMOPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 942427)),
#  ('ROUTINEPARMS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 959155)),
#  ('ROUTINES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 36, 987288)),
#  ('ROUTINESFEDERATED', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 79044)),
#  ('ROWFIELDS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 96316)),
#  ('SCHEMAAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 115711)),
#  ('SCHEMATA', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 141207)),
#  ('SCPREFTBSPACES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 179081)),
#  ('SECURITYLABELACCESS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 208637)),
#  ('SECURITYLABELCOMPONENTELEMENTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 231491)),
#  ('SECURITYLABELCOMPONENTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 247586)),
#  ('SECURITYLABELS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 265424)),
#  ('SECURITYPOLICIES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 280755)),
#  ('SECURITYPOLICYCOMPONENTRULES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 301375)),
#  ('SECURITYPOLICYEXEMPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 319370)),
#  ('SEQUENCEAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 341857)),
#  ('SEQUENCES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 372951)),
#  ('SERVEROPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 400231)),
#  ('SERVERS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 421335)),
#  ('SERVICECLASSES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 440624)),
#  ('STATEMENTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 456239)),
#  ('STATEMENTTEXTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 472437)),
#  ('STOGROUPS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 490069)),
#  ('SURROGATEAUTHIDS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 506466)),
#  ('TABAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 528367)),
#  ('TABCONST', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 573424)),
#  ('TABDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 594299)),
#  ('TABDETACHEDDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 625704)),
#  ('TABLES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 37, 645800)),
#  ('TABLESPACES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 46, 792638)),
#  ('TABOPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 46, 813838)),
#  ('TBSPACEAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 46, 827708)),
#  ('THRESHOLDS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 46, 856159)),
#  ('TRANSFORMS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 46, 875839)),
#  ('TRIGDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 46, 893621)),
#  ('TRIGGERS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 46, 921642)),
#  ('TYPEMAPPINGS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 46, 972614)),
#  ('USAGELISTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 46, 990143)),
#  ('USEROPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 14044)),
#  ('VARIABLEAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 38632)),
#  ('VARIABLEDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 78210)),
#  ('VARIABLES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 102901)),
#  ('VIEWDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 121200)),
#  ('VIEWS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 137921)),
#  ('WORKACTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 159097)),
#  ('WORKACTIONSETS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 175289)),
#  ('WORKCLASSATTRIBUTES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 197848)),
#  ('WORKCLASSES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 213038)),
#  ('WORKCLASSSETS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 229144)),
#  ('WORKLOADAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 247097)),
#  ('WORKLOADCONNATTR', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 268294)),
#  ('WORKLOADS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 282502)),
#  ('WRAPOPTIONS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 297022)),
#  ('WRAPPERS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 313036)),
#  ('XDBMAPGRAPHS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 330538)),
#  ('XDBMAPSHREDTREES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 369171)),
#  ('XMLSTRINGS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 389954)),
#  ('XSROBJECTAUTH', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 402049)),
#  ('XSROBJECTCOMPONENTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 434102)),
#  ('XSROBJECTDEP', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 462760)),
#  ('XSROBJECTDETAILS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 475116)),
#  ('XSROBJECTHIERARCHIES', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 486769)),
#  ('XSROBJECTS', 'SYSCAT  ', datetime.datetime(2022, 10, 19, 21, 59, 47, 499600)),
#  ('COLDIST', 'SYSSTAT ', datetime.datetime(2022, 10, 19, 21, 59, 47, 513344)),
#  ('COLGROUPDIST', 'SYSSTAT ', datetime.datetime(2022, 10, 19, 21, 59, 47, 532970)),
#  ('COLGROUPDISTCOUNTS', 'SYSSTAT ', datetime.datetime(2022, 10, 19, 21, 59, 47, 545887)),
#  ('COLGROUPS', 'SYSSTAT ', datetime.datetime(2022, 10, 19, 21, 59, 47, 559051)),
#  ('COLUMNS', 'SYSSTAT ', datetime.datetime(2022, 10, 19, 21, 59, 47, 572420)),
#  ('FUNCTIONS', 'SYSSTAT ', datetime.datetime(2022, 10, 19, 21, 59, 47, 609237)),
#  ('INDEXES', 'SYSSTAT ', datetime.datetime(2022, 10, 19, 21, 59, 47, 627684)),
#  ('ROUTINES', 'SYSSTAT ', datetime.datetime(2022, 10, 19, 21, 59, 47, 659004)),
#  ('TABLES', 'SYSSTAT ', datetime.datetime(2022, 10, 19, 21, 59, 47, 673430)),
#  ('SQLCOLPRIVILEGES', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 288337)),
#  ('SQLCOLUMNS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 335444)),
#  ('SQLFOREIGNKEYS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 387749)),
#  ('SQLPRIMARYKEYS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 404443)),
#  ('SQLPROCEDURECOLS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 418121)),
#  ('SQLPROCEDURES', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 443236)),
#  ('SQLSPECIALCOLUMNS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 456331)),
#  ('SQLSTATISTICS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 473454)),
#  ('SQLTABLEPRIVILEGES', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 488928)),
#  ('SQLTABLETYPES', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 515298)),
#  ('SQLSCHEMAS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 527514)),
#  ('SQLTABLES', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 536087)),
#  ('SQLUDTS', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 550476)),
#  ('SQLTYPEINFO', 'SYSIBM  ', datetime.datetime(2022, 10, 19, 21, 59, 57, 564606)),
#  ('SNAPAGENT', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 586928)),
#  ('SNAPAGENT_MEMORY_POOL', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 608326)),
#  ('SNAPAPPL', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 624113)),
#  ('SNAPAPPL_INFO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 659076)),
#  ('SNAPBP', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 690687)),
#  ('SNAPBP_PART', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 727178)),
#  ('SNAPCONTAINER', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 742399)),
#  ('SNAPDB', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 762188)),
#  ('SNAPDB_MEMORY_POOL', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 834318)),
#  ('SNAPDBM', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 852608)),
#  ('SNAPDBM_MEMORY_POOL', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 869612)),
#  ('SNAPDETAILLOG', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 884419)),
#  ('SNAPDYN_SQL', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 899609)),
#  ('SNAPFCM', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 920508)),
#  ('SNAPFCM_PART', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 939202)),
#  ('SNAPHADR', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 958835)),
#  ('SNAPLOCK', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 978825)),
#  ('SNAPLOCKWAIT', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 57, 999994)),
#  ('SNAPSTMT', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 17987)),
#  ('SNAPSTORAGE_PATHS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 44616)),
#  ('SNAPSUBSECTION', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 62721)),
#  ('SNAPSWITCHES', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 78878)),
#  ('SNAPTAB_REORG', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 95435)),
#  ('SNAPTAB', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 111398)),
#  ('SNAPTBSP', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 130249)),
#  ('SNAPTBSP_PART', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 161587)),
#  ('SNAPTBSP_QUIESCER', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 183570)),
#  ('SNAPTBSP_RANGE', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 198285)),
#  ('SNAPUTIL', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 223169)),
#  ('SNAPUTIL_PROGRESS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 240101)),
#  ('REG_VARIABLES', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 255893)),
#  ('ENV_SYS_INFO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 270110)),
#  ('ENV_PROD_INFO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 286591)),
#  ('ENV_INST_INFO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 301868)),
#  ('ENV_FEATURE_INFO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 320681)),
#  ('DB_HISTORY', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 344115)),
#  ('PDLOGMSGS_LAST24HOURS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 371220)),
#  ('AUTHORIZATIONIDS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 388912)),
#  ('PRIVILEGES', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 425178)),
#  ('OBJECTOWNERS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 463605)),
#  ('ADMINTABINFO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 494555)),
#  ('ADMINTABCOMPRESSINFO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 521460)),
#  ('NOTIFICATIONLIST', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 537614)),
#  ('CONTACTGROUPS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 570165)),
#  ('CONTACTS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 602461)),
#  ('DBCFG', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 625936)),
#  ('DBMCFG', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 685827)),
#  ('DBPATHS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 709576)),
#  ('APPLICATIONS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 727600)),
#  ('APPL_PERFORMANCE', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 747652)),
#  ('BP_HITRATIO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 762433)),
#  ('BP_READ_IO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 778132)),
#  ('BP_WRITE_IO', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 795605)),
#  ('CONTAINER_UTILIZATION', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 810028)),
#  ('LOCKS_HELD', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 827258)),
#  ('LOCKWAITS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 846559)),
#  ('LOG_UTILIZATION', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 868625)),
#  ('LONG_RUNNING_SQL', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 881614)),
#  ('QUERY_PREP_COST', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 898951)),
#  ('TBSP_UTILIZATION', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 912427)),
#  ('TOP_DYNAMIC_SQL', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 931090)),
#  ('MON_BP_UTILIZATION', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 945872)),
#  ('MON_TBSP_UTILIZATION', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 971855)),
#  ('MON_PKG_CACHE_SUMMARY', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 58, 995303)),
#  ('MON_CURRENT_SQL', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 19840)),
#  ('MON_CURRENT_UOW', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 50115)),
#  ('MON_SERVICE_SUBCLASS_SUMMARY', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 85398)),
#  ('MON_WORKLOAD_SUMMARY', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 138568)),
#  ('MON_CONNECTION_SUMMARY', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 171096)),
#  ('MON_DB_SUMMARY', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 205443)),
#  ('ENV_SYS_RESOURCES', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 235252)),
#  ('ADMINTEMPTABLES', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 253586)),
#  ('ADMINTEMPCOLUMNS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 267176)),
#  ('MON_LOCKWAITS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 287853)),
#  ('ENV_CF_SYS_RESOURCES', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 330334)),
#  ('DB2_CLUSTER_HOST_STATE', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 343634)),
#  ('DB2_CF', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 359655)),
#  ('DB2_MEMBER', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 375765)),
#  ('DB2_INSTANCE_ALERTS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 391669)),
#  ('MON_TRANSACTION_LOG_UTILIZATION', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 410326)),
#  ('INGEST_USER_CONNECTIONS', 'SYSIBMADM', datetime.datetime(2022, 10, 19, 21, 59, 59, 431470)),
#  ('MESSAGES', 'SYSTOOLS', datetime.datetime(2021, 6, 17, 18, 27, 9, 875439)),
#  ('STMG_DBSIZE_INFO', 'SYSTOOLS', datetime.datetime(2021, 7, 12, 14, 0, 46, 94670)),
#  ('ADMINTASKS', 'SYSTOOLS', datetime.datetime(2022, 6, 25, 16, 43, 33, 866497)),
#  ('ADMINTASKSTATUS', 'SYSTOOLS', datetime.datetime(2022, 6, 25, 16, 43, 33, 964383)),
#  ('ADMIN_TASK_LIST', 'SYSTOOLS', datetime.datetime(2022, 6, 25, 16, 43, 34, 21450)),
#  ('ADMIN_TASK_STATUS', 'SYSTOOLS', datetime.datetime(2022, 6, 25, 16, 43, 34, 35774)),
#  ('EMPLOYEES', 'DVX78774', datetime.datetime(2022, 10, 23, 9, 10, 42, 110492)),
#  ('JOB_HISTORY', 'DVX78774', datetime.datetime(2022, 10, 23, 9, 10, 42, 198929)),
#  ('JOBS', 'DVX78774', datetime.datetime(2022, 10, 23, 9, 10, 42, 285770)),
#  ('DEPARTMENTS', 'DVX78774', datetime.datetime(2022, 10, 23, 9, 10, 42, 369965)),
#  ('LOCATIONS', 'DVX78774', datetime.datetime(2022, 10, 23, 9, 10, 42, 456547)),
#  ('INSTRUCTOR', 'DVX78774', datetime.datetime(2022, 10, 25, 18, 7, 4, 904487)),
#  ('INTERNATIONAL_STUDENT_TEST_SCORES', 'DVX78774', datetime.datetime(2022, 10, 26, 9, 11, 29, 880341)),
#  ('CHICAGO_SOCIOECONOMIC_DATA', 'DVX78774', datetime.datetime(2022, 10, 26, 15, 58, 42, 870675)),
#  ('SCHOOLS', 'DVX78774', datetime.datetime(2022, 10, 27, 9, 31, 56, 431841))]

# %%
# %sql select * from SYSCAT.TABLES where TABNAME='SCHOOLS'
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('DVX78774', 'SCHOOLS', 'DVX78774', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2022, 10, 27, 9, 31, 56, 431841), datetime.datetime(2022, 10, 27, 9, 31, 56, 431841), datetime.datetime(2022, 10, 27, 9, 31, 56, 431841), datetime.datetime(2022, 10, 27, 9, 33, 8, 547113), 78, 12, 2818, 566, 15, 0, 16, -1, -1, -1, 0, 'DVX78774SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2022, 10, 27, 9, 31, 56, 431841), 0, ' ', None, None, 'N', 'DVX78774', ' ', ' ', ' ', datetime.date(2022, 10, 27), ' ', 'N', 'R', 'N', -1.0, None)]

# %%
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES \
      where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('DVX78774', 'EMPLOYEES', datetime.datetime(2022, 10, 23, 9, 10, 42, 110492)),
#  ('DVX78774', 'JOB_HISTORY', datetime.datetime(2022, 10, 23, 9, 10, 42, 198929)),
#  ('DVX78774', 'JOBS', datetime.datetime(2022, 10, 23, 9, 10, 42, 285770)),
#  ('DVX78774', 'DEPARTMENTS', datetime.datetime(2022, 10, 23, 9, 10, 42, 369965)),
#  ('DVX78774', 'LOCATIONS', datetime.datetime(2022, 10, 23, 9, 10, 42, 456547)),
#  ('DVX78774', 'INSTRUCTOR', datetime.datetime(2022, 10, 25, 18, 7, 4, 904487)),
#  ('DVX78774', 'INTERNATIONAL_STUDENT_TEST_SCORES', datetime.datetime(2022, 10, 26, 9, 11, 29, 880341)),
#  ('DVX78774', 'CHICAGO_SOCIOECONOMIC_DATA', datetime.datetime(2022, 10, 26, 15, 58, 42, 870675)),
#  ('DVX78774', 'SCHOOLS', datetime.datetime(2022, 10, 27, 9, 31, 56, 431841))]

# %%
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME='SCHOOLS'
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [(78,)]

# %%
# %sql select COLNAME,TYPENAME,LENGTH from SYSCAT.COLUMNS where TABNAME='SCHOOLS'
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('SCHOOL_ID', 'INTEGER', 4),
#  ('NAME_OF_SCHOOL', 'VARCHAR', 64),
#  ('Elementary, Middle, or High School', 'VARCHAR', 2),
#  ('STREET_ADDRESS', 'VARCHAR', 29),
#  ('CITY', 'VARCHAR', 7),
#  ('STATE', 'VARCHAR', 2),
#  ('ZIP_CODE', 'INTEGER', 4),
#  ('PHONE_NUMBER', 'VARCHAR', 14),
#  ('LINK', 'VARCHAR', 78),
#  ('NETWORK_MANAGER', 'VARCHAR', 40),
#  ('COLLABORATIVE_NAME', 'VARCHAR', 34),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'VARCHAR', 3),
#  ('TRACK_SCHEDULE', 'VARCHAR', 12),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR', 16),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR', 15),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR', 3),
#  ('SAFETY_ICON', 'VARCHAR', 11),
#  ('SAFETY_SCORE', 'SMALLINT', 2),
#  ('FAMILY_INVOLVEMENT_ICON', 'VARCHAR', 11),
#  ('FAMILY_INVOLVEMENT_SCORE', 'VARCHAR', 3),
#  ('ENVIRONMENT_ICON', 'VARCHAR', 11),
#  ('ENVIRONMENT_SCORE', 'SMALLINT', 2),
#  ('INSTRUCTION_ICON', 'VARCHAR', 11),
#  ('INSTRUCTION_SCORE', 'SMALLINT', 2),
#  ('LEADERS_ICON', 'VARCHAR', 4),
#  ('LEADERS_SCORE', 'VARCHAR', 3),
#  ('TEACHERS_ICON', 'VARCHAR', 11),
#  ('TEACHERS_SCORE', 'VARCHAR', 3),
#  ('PARENT_ENGAGEMENT_ICON', 'VARCHAR', 7),
#  ('PARENT_ENGAGEMENT_SCORE', 'VARCHAR', 3),
#  ('PARENT_ENVIRONMENT_ICON', 'VARCHAR', 7),
#  ('PARENT_ENVIRONMENT_SCORE', 'VARCHAR', 3),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR', 6),
#  ('RATE_OF_MISCONDUCTS__PER_100_STUDENTS_', 'DECIMAL', 5),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'VARCHAR', 6),
#  ('INDIVIDUALIZED_EDUCATION_PROGRAM_COMPLIANCE_RATE', 'VARCHAR', 7),
#  ('PK_2_LITERACY__', 'VARCHAR', 4),
#  ('PK_2_MATH__', 'VARCHAR', 4),
#  ('GR3_5_GRADE_LEVEL_MATH__', 'VARCHAR', 4),
#  ('GR3_5_GRADE_LEVEL_READ__', 'VARCHAR', 4),
#  ('GR3_5_KEEP_PACE_READ__', 'VARCHAR', 4),
#  ('GR3_5_KEEP_PACE_MATH__', 'VARCHAR', 4),
#  ('GR6_8_GRADE_LEVEL_MATH__', 'VARCHAR', 4),
#  ('GR6_8_GRADE_LEVEL_READ__', 'VARCHAR', 4),
#  ('GR6_8_KEEP_PACE_MATH_', 'VARCHAR', 4),
#  ('GR6_8_KEEP_PACE_READ__', 'VARCHAR', 4),
#  ('GR_8_EXPLORE_MATH__', 'VARCHAR', 4),
#  ('GR_8_EXPLORE_READ__', 'VARCHAR', 4),
#  ('ISAT_EXCEEDING_MATH__', 'DECIMAL', 4),
#  ('ISAT_EXCEEDING_READING__', 'DECIMAL', 4),
#  ('ISAT_VALUE_ADD_MATH', 'DECIMAL', 3),
#  ('ISAT_VALUE_ADD_READ', 'DECIMAL', 3),
#  ('ISAT_VALUE_ADD_COLOR_MATH', 'VARCHAR', 6),
#  ('ISAT_VALUE_ADD_COLOR_READ', 'VARCHAR', 6),
#  ('STUDENTS_TAKING__ALGEBRA__', 'VARCHAR', 4),
#  ('STUDENTS_PASSING__ALGEBRA__', 'VARCHAR', 4),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR', 4),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR', 4),
#  ('10th Grade PLAN (2009)', 'VARCHAR', 4),
#  ('10th Grade PLAN (2010)', 'VARCHAR', 4),
#  ('NET_CHANGE_EXPLORE_AND_PLAN', 'VARCHAR', 3),
#  ('11th Grade Average ACT (2011)', 'VARCHAR', 4),
#  ('NET_CHANGE_PLAN_AND_ACT', 'VARCHAR', 3),
#  ('COLLEGE_ELIGIBILITY__', 'VARCHAR', 4),
#  ('GRADUATION_RATE__', 'VARCHAR', 4),
#  ('COLLEGE_ENROLLMENT_RATE__', 'VARCHAR', 4),
#  ('COLLEGE_ENROLLMENT', 'SMALLINT', 2),
#  ('GENERAL_SERVICES_ROUTE', 'SMALLINT', 2),
#  ('FRESHMAN_ON_TRACK_RATE__', 'VARCHAR', 4),
#  ('X_COORDINATE', 'DECIMAL', 13),
#  ('Y_COORDINATE', 'DECIMAL', 13),
#  ('LATITUDE', 'DECIMAL', 18),
#  ('LONGITUDE', 'DECIMAL', 18),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR', 22),
#  ('WARD', 'SMALLINT', 2),
#  ('POLICE_DISTRICT', 'SMALLINT', 2),
#  ('LOCATION', 'VARCHAR', 27)]

# %%
# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('10th Grade PLAN (2009)', 'VARCHAR ', 4),
#  ('10th Grade PLAN (2010)', 'VARCHAR ', 4),
#  ('11th Grade Average ACT (2011)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR ', 4),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'VARCHAR ', 3),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR ', 6),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'VARCHAR ', 6),
#  ('CITY', 'VARCHAR ', 7),
#  ('COLLABORATIVE_NAME', 'VARCHAR ', 34),
#  ('COLLEGE_ELIGIBILITY__', 'VARCHAR ', 4),
#  ('COLLEGE_ENROLLMENT', 'SMALLINT', 2),
#  ('COLLEGE_ENROLLMENT_RATE__', 'VARCHAR ', 4),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR ', 22),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR ', 15),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR ', 16),
#  ('ENVIRONMENT_ICON', 'VARCHAR ', 11),
#  ('ENVIRONMENT_SCORE', 'SMALLINT', 2),
#  ('Elementary, Middle, or High School', 'VARCHAR ', 2),
#  ('FAMILY_INVOLVEMENT_ICON', 'VARCHAR ', 11),
#  ('FAMILY_INVOLVEMENT_SCORE', 'VARCHAR ', 3),
#  ('FRESHMAN_ON_TRACK_RATE__', 'VARCHAR ', 4),
#  ('GENERAL_SERVICES_ROUTE', 'SMALLINT', 2),
#  ('GR3_5_GRADE_LEVEL_MATH__', 'VARCHAR ', 4),
#  ('GR3_5_GRADE_LEVEL_READ__', 'VARCHAR ', 4),
#  ('GR3_5_KEEP_PACE_MATH__', 'VARCHAR ', 4),
#  ('GR3_5_KEEP_PACE_READ__', 'VARCHAR ', 4),
#  ('GR6_8_GRADE_LEVEL_MATH__', 'VARCHAR ', 4),
#  ('GR6_8_GRADE_LEVEL_READ__', 'VARCHAR ', 4),
#  ('GR6_8_KEEP_PACE_MATH_', 'VARCHAR ', 4),
#  ('GR6_8_KEEP_PACE_READ__', 'VARCHAR ', 4),
#  ('GRADUATION_RATE__', 'VARCHAR ', 4),
#  ('GR_8_EXPLORE_MATH__', 'VARCHAR ', 4),
#  ('GR_8_EXPLORE_READ__', 'VARCHAR ', 4),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR ', 3),
#  ('INDIVIDUALIZED_EDUCATION_PROGRAM_COMPLIANCE_RATE', 'VARCHAR ', 7),
#  ('INSTRUCTION_ICON', 'VARCHAR ', 11),
#  ('INSTRUCTION_SCORE', 'SMALLINT', 2),
#  ('ISAT_EXCEEDING_MATH__', 'DECIMAL ', 4),
#  ('ISAT_EXCEEDING_READING__', 'DECIMAL ', 4),
#  ('ISAT_VALUE_ADD_COLOR_MATH', 'VARCHAR ', 6),
#  ('ISAT_VALUE_ADD_COLOR_READ', 'VARCHAR ', 6),
#  ('ISAT_VALUE_ADD_MATH', 'DECIMAL ', 3),
#  ('ISAT_VALUE_ADD_READ', 'DECIMAL ', 3),
#  ('LATITUDE', 'DECIMAL ', 18),
#  ('LEADERS_ICON', 'VARCHAR ', 4),
#  ('LEADERS_SCORE', 'VARCHAR ', 3),
#  ('LINK', 'VARCHAR ', 78),
#  ('LOCATION', 'VARCHAR ', 27),
#  ('LONGITUDE', 'DECIMAL ', 18),
#  ('NAME_OF_SCHOOL', 'VARCHAR ', 64),
#  ('NETWORK_MANAGER', 'VARCHAR ', 40),
#  ('NET_CHANGE_EXPLORE_AND_PLAN', 'VARCHAR ', 3),
#  ('NET_CHANGE_PLAN_AND_ACT', 'VARCHAR ', 3),
#  ('PARENT_ENGAGEMENT_ICON', 'VARCHAR ', 7),
#  ('PARENT_ENGAGEMENT_SCORE', 'VARCHAR ', 3),
#  ('PARENT_ENVIRONMENT_ICON', 'VARCHAR ', 7),
#  ('PARENT_ENVIRONMENT_SCORE', 'VARCHAR ', 3),
#  ('PHONE_NUMBER', 'VARCHAR ', 14),
#  ('PK_2_LITERACY__', 'VARCHAR ', 4),
#  ('PK_2_MATH__', 'VARCHAR ', 4),
#  ('POLICE_DISTRICT', 'SMALLINT', 2),
#  ('RATE_OF_MISCONDUCTS__PER_100_STUDENTS_', 'DECIMAL ', 5),
#  ('SAFETY_ICON', 'VARCHAR ', 11),
#  ('SAFETY_SCORE', 'SMALLINT', 2),
#  ('SCHOOL_ID', 'INTEGER ', 4),
#  ('STATE', 'VARCHAR ', 2),
#  ('STREET_ADDRESS', 'VARCHAR ', 29),
#  ('STUDENTS_PASSING__ALGEBRA__', 'VARCHAR ', 4),
#  ('STUDENTS_TAKING__ALGEBRA__', 'VARCHAR ', 4),
#  ('TEACHERS_ICON', 'VARCHAR ', 11),
#  ('TEACHERS_SCORE', 'VARCHAR ', 3),
#  ('TRACK_SCHEDULE', 'VARCHAR ', 12),
#  ('WARD', 'SMALLINT', 2),
#  ('X_COORDINATE', 'DECIMAL ', 13),
#  ('Y_COORDINATE', 'DECIMAL ', 13),
#  ('ZIP_CODE', 'INTEGER ', 4)]

# %%
# %sql select count(*) from SCHOOLS where "Elementary, Middle, or High School" = 'ES'
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0104N  An unexpected token "," was found following "OLS where Elementary".  Expected tokens may include:  "(".  SQLSTATE=42601\r SQLCODE=-104
# [SQL: select count(*) from SCHOOLS where Elementary, Middle, or High School = 'ES']
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
# %sql select max(SAFETY_SCORE) as MAX_SAFETY_SCORE from SCHOOLS
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [(99,)]

# %%
# %sql select NAME_OF_SCHOOL from SCHOOLS where SAFETY_SCORE=(select max(SAFETY_SCORE) from SCHOOLS)
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('Abraham Lincoln Elementary School',),
#  ('Alexander Graham Bell Elementary School',),
#  ('Annie Keller Elementary Gifted Magnet School',),
#  ('Augustus H Burley Elementary School',),
#  ('Edgar Allan Poe Elementary Classical School',),
#  ('Edgebrook Elementary School',),
#  ('Ellen Mitchell Elementary School',),
#  ('James E McDade Elementary Classical School',),
#  ('James G Blaine Elementary School',),
#  ('LaSalle Elementary Language Academy',),
#  ('Mary E Courtenay Elementary Language Arts Center',),
#  ('Northside College Preparatory High School',),
#  ('Northside Learning Center High School',),
#  ('Norwood Park Elementary School',),
#  ('Oriole Park Elementary School',),
#  ('Sauganash Elementary School',),
#  ('Stephen Decatur Classical Elementary School',),
#  ('Talman Elementary School',),
#  ('Wildwood Elementary School',)]

# %%
# %sql select NAME_OF_SCHOOL,AVERAGE_STUDENT_ATTENDANCE from SCHOOLS order by AVERAGE_STUDENT_ATTENDANCE desc nulls last limit 10
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %%
# %sql select NAME_OF_SCHOOL,AVERAGE_STUDENT_ATTENDANCE from SCHOOLS order by AVERAGE_STUDENT_ATTENDANCE fetch first 5 rows only
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %%
# %sql SELECT Name_of_School, REPLACE(Average_Student_Attendance, '%', '') \
     from SCHOOLS \
     order by Average_Student_Attendance \
     fetch first 5 rows only
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %%
# %sql select NAME_OF_SCHOOL,AVERAGE_STUDENT_ATTENDANCE \
        from SCHOOLS \
        where AVERAGE_STUDENT_ATTENDANCE<'70.00%'
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Dyett High School', '62.50%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Roberto Clemente Community Academy High School', '69.60%'),
#  ('Wendell Phillips Academy High School', '63.00%')]

# %%
# %sql SELECT Name_of_School, Average_Student_Attendance  \
     from SCHOOLS \
     where CAST ( REPLACE(Average_Student_Attendance, '%', '') AS DOUBLE ) < 70 \
     order by Average_Student_Attendance
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %%
# %sql SELECT Name_of_School, Average_Student_Attendance  \
     from SCHOOLS \
     where DECIMAL ( REPLACE(Average_Student_Attendance, '%', '') ) < 70 \
     order by Average_Student_Attendance
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %%
# %sql select COMMUNITY_AREA_NAME,sum(COLLEGE_ENROLLMENT) from SCHOOLS group by COMMUNITY_AREA_NAME
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('ALBANY PARK', 6864),
#  ('ARCHER HEIGHTS', 4823),
#  ('ARMOUR SQUARE', 1458),
#  ('ASHBURN', 6483),
#  ('AUBURN GRESHAM', 4175),
#  ('AUSTIN', 10933),
#  ('AVALON PARK', 1522),
#  ('AVONDALE', 3640),
#  ('BELMONT CRAGIN', 14386),
#  ('BEVERLY', 1636),
#  ('BRIDGEPORT', 3167),
#  ('BRIGHTON PARK', 9647),
#  ('BURNSIDE', 549),
#  ('CALUMET HEIGHTS', 1568),
#  ('CHATHAM', 5042),
#  ('CHICAGO LAWN', 7086),
#  ('CLEARING', 2085),
#  ('DOUGLAS', 4670),
#  ('DUNNING', 4568),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('EDGEWATER', 4600),
#  ('EDISON PARK', 910),
#  ('ENGLEWOOD', 6832),
#  ('FOREST GLEN', 1431),
#  ('FULLER PARK', 531),
#  ('GAGE PARK', 9915),
#  ('GARFIELD RIDGE', 4552),
#  ('GRAND BOULEVARD', 2809),
#  ('GREATER GRAND CROSSING', 4051),
#  ('HEGEWISCH', 963),
#  ('HERMOSA', 3975),
#  ('HUMBOLDT PARK', 8620),
#  ('HYDE PARK', 1930),
#  ('IRVING PARK', 7764),
#  ('JEFFERSON PARK', 1755),
#  ('KENWOOD', 4287),
#  ('LAKE VIEW', 7055),
#  ('LINCOLN PARK', 5615),
#  ('LINCOLN SQUARE', 4132),
#  ('LOGAN SQUARE', 7351),
#  ('LOOP', 871),
#  ('LOWER WEST SIDE', 7257),
#  ('MCKINLEY PARK', 1552),
#  ('MONTCLARE', 1317),
#  ('MORGAN PARK', 3271),
#  ('MOUNT GREENWOOD', 2091),
#  ('NEAR NORTH SIDE', 3362),
#  ('NEAR SOUTH SIDE', 1378),
#  ('NEAR WEST SIDE', 7975),
#  ('NEW CITY', 7922),
#  ('NORTH CENTER', 7541),
#  ('NORTH LAWNDALE', 5146),
#  ('NORTH PARK', 4210),
#  ('NORWOOD PARK', 6469),
#  ('OAKLAND', 140),
#  ('OHARE', 786),
#  ('PORTAGE PARK', 6954),
#  ('PULLMAN', 1620),
#  ('RIVERDALE', 1547),
#  ('ROGERS PARK', 4068),
#  ('ROSELAND', 7020),
#  ('SOUTH CHICAGO', 4043),
#  ('SOUTH DEERING', 1859),
#  ('SOUTH LAWNDALE', 14793),
#  ('SOUTH SHORE', 4543),
#  ('UPTOWN', 4388),
#  ('WASHINGTON HEIGHTS', 4006),
#  ('WASHINGTON PARK', 2648),
#  ('WEST ELSDON', 3700),
#  ('WEST ENGLEWOOD', 5946),
#  ('WEST GARFIELD PARK', 2622),
#  ('WEST LAWN', 4207),
#  ('WEST PULLMAN', 3240),
#  ('WEST RIDGE', 8197),
#  ('WEST TOWN', 9429),
#  ('WOODLAWN', 4206)]

# %%
# %sql select COMMUNITY_AREA_NAME,sum(COLLEGE_ENROLLMENT) from SCHOOLS \
            group by COMMUNITY_AREA_NAME order by sum(COLLEGE_ENROLLMENT) limit 5
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %%
# %sql select NAME_OF_SCHOOL,SAFETY_SCORE from SCHOOLS order by SAFETY_SCORE FETCH FIRST 5 ROWS ONLY
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('Edmond Burke Elementary School', 1),
#  ("Luke O'Toole Elementary School", 5),
#  ('George W Tilton Elementary School', 6),
#  ('Foster Park Elementary School', 11),
#  ('Emil G Hirsch Metropolitan High School', 13)]

# %%
# %%sql
# select hardship_index
#    from chicago_socioeconomic_data CD, schools CPS
#    where CD.ca = CPS.community_area_number
#       and college_enrollment = 4368
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [(6.0,)]

# %%
# %sql select ca, community_area_name, hardship_index from chicago_socioeconomic_data \
   where ca in \
   ( select community_area_number from schools order by college_enrollment desc limit 1 )
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [(5.0, 'North Center', 6.0)]
